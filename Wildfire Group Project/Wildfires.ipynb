# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_variables = pd.read_csv('_variable_descriptions.csv')

# %%
# Contains decription of features. 
df_variables
# Out:
#                          Table                       Variable  \
# 0                        Fires                         FOD_ID
# 1                        Fires                         FPA_ID
# 2                        Fires             SOURCE_SYSTEM_TYPE
# 3                        Fires                  SOURCE_SYSTEM
# 4                        Fires          NWCG_REPORTING_AGENCY
# 5                        Fires         NWCG_REPORTING_UNIT_ID
# 6                        Fires       NWCG_REPORTING_UNIT_NAME
# 7                        Fires          SOURCE_REPORTING_UNIT
# 8                        Fires     SOURCE_REPORTING_UNIT_NAME
# 9                        Fires           LOCAL_FIRE_REPORT_ID
# 10                       Fires              LOCAL_INCIDENT_ID
# 11                       Fires                      FIRE_CODE
# 12                       Fires                      FIRE_NAME
# 13                       Fires  ICS_209_PLUS_INCIDENT_JOIN_ID
# ...

# %%
df = pd.read_csv('data.csv')
# Out:
# /var/folders/p6/55lhxkcd0lng_fsbn4cj3qmh0000gn/T/ipykernel_55315/1507164070.py:1: DtypeWarning: Columns (9,11,12,13,14,15,16,17,18,19,26,27,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (2303566, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2303566 entries, 0 to 2303565
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   OBJECTID                       int64
#  1   Shape                          object
#  2   FOD_ID                         int64
#  3   FPA_ID                         object
#  4   SOURCE_SYSTEM_TYPE             object
#  5   SOURCE_SYSTEM                  object
#  6   NWCG_REPORTING_AGENCY          object
#  7   NWCG_REPORTING_UNIT_ID         object
#  8   NWCG_REPORTING_UNIT_NAME       object
#  9   SOURCE_REPORTING_UNIT          object
#  10  SOURCE_REPORTING_UNIT_NAME     object
#  11  LOCAL_FIRE_REPORT_ID           object
#  12  LOCAL_INCIDENT_ID              object
#  13  FIRE_CODE                      object
#  14  FIRE_NAME                      object
#  15  ICS_209_PLUS_INCIDENT_JOIN_ID  object
#  16  ICS_209_PLUS_COMPLEX_JOIN_ID   object
# ...

# %%
df.describe().round(2).T
# Out:
#                     count          mean           std      min        25%  \
# OBJECTID        2303566.0  1.151784e+06  6.649824e+05     1.00  575892.25
# FOD_ID          2303566.0  1.185100e+08  1.621564e+08     1.00  622549.25
# FIRE_YEAR       2303566.0  2.006170e+03  8.040000e+00  1992.00    2000.00
# DISCOVERY_DOY   2303566.0  1.659700e+02  8.975000e+01     1.00      91.00
# DISCOVERY_TIME  1514471.0  1.445250e+03  4.253700e+02     0.00    1234.00
# CONT_DOY        1408753.0  1.707600e+02  8.626000e+01     1.00      99.00
# CONT_TIME       1312686.0  1.523730e+03  4.461000e+02     0.00    1303.00
# FIRE_SIZE       2303566.0  7.816000e+01  2.630830e+03     0.00       0.10
# LATITUDE        2303566.0  3.697000e+01  6.010000e+00    17.94      33.01
# LONGITUDE       2303566.0 -9.636000e+01  1.664000e+01  -178.80    -111.04
# FIPS_CODE       1637787.0  2.741364e+04  1.694484e+04  1001.00   12101.00
#
#                        50%           75%           max
# ...

# %%
# Shape is not listed on the variable df. Is it relevant? Which features are definitely not needed?
df.head().T
# Out:
#                                                                                0  \
# OBJECTID                                                                       1
# Shape                          b'\x00\x01\xad\x10\x00\x00\xc8\xce\n[_@^\xc0\x...
# FOD_ID                                                                         1
# FPA_ID                                                                FS-1418826
# SOURCE_SYSTEM_TYPE                                                           FED
# SOURCE_SYSTEM                                                        FS-FIRESTAT
# NWCG_REPORTING_AGENCY                                                         FS
# NWCG_REPORTING_UNIT_ID                                                   USCAPNF
# NWCG_REPORTING_UNIT_NAME                                  Plumas National Forest
# SOURCE_REPORTING_UNIT                                                        511
# SOURCE_REPORTING_UNIT_NAME                                Plumas National Forest
# ...

# %%
len(df['COMPLEX_NAME'].unique())
# Out:
# 1535

# %%
# Note high amount of missing data in certain features. All other features are not missing data.
missing = pd.concat([df.isnull().sum(), (100 * df.isnull().mean()).round(2)], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False).head(17)
# Out:
#                                  count      %
# ICS_209_PLUS_COMPLEX_JOIN_ID   2298627  99.79
# COMPLEX_NAME                   2297619  99.74
# MTBS_FIRE_NAME                 2289696  99.40
# MTBS_ID                        2289696  99.40
# ICS_209_PLUS_INCIDENT_JOIN_ID  2270072  98.55
# NWCG_CAUSE_AGE_CATEGORY        2228039  96.72
# FIRE_CODE                      1906254  82.75
# LOCAL_FIRE_REPORT_ID           1825891  79.26
# FIRE_NAME                       995415  43.21
# CONT_TIME                       990880  43.02
# CONT_DOY                        894813  38.84
# CONT_DATE                       894813  38.84
# DISCOVERY_TIME                  789095  34.26
# LOCAL_INCIDENT_ID               744411  32.32
# FIPS_NAME                       665780  28.90
# FIPS_CODE                       665779  28.90
# COUNTY                          665779  28.90

# %%
# What are listed causes of fires?
df.NWCG_CAUSE_CLASSIFICATION.unique()
# Out:
# array(['Human', 'Natural', 'Missing data/not specified/undetermined'],
#       dtype=object)

# %%
# Why are there numbers in county? How many of the entries are a number?
df.COUNTY.unique()
# Out:
# array([63.0, 61.0, 17.0, ..., 'Porter', 'Hopewell',
#        'District of Columbia'], dtype=object)

# %%
# Confirm entries are present for all years. 
df.FIRE_YEAR.sort_values().unique()
# Out:
# array([1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020])
